# %%
# from huggingface_hub import hf_hub_download
# hf_hub_download(repo_id="xzyhku/flux_hpsv2.1_dancegrpo", filename="checkpoint-ema-300-0/diffusion_pytorch_model.safetensors", local_dir="./flux/flux/transformer", local_dir_use_symlinks=False)

# %%
import torch
from diffusers import FluxPipeline, FluxTransformer2DModel, ConfigMixin
from transformers import AutoConfig

# %%
model = FluxTransformer2DModel.from_single_file("./flux/flux/transformer/diffusion_pytorch_model.safetensors", config="config.json", torch_dtype=torch.bfloat16)

# %%
import torch
from diffusers import FluxPipeline, FluxTransformer2DModel, ConfigMixin
model = FluxTransformer2DModel.from_single_file("./flux/flux/transformer/diffusion_pytorch_model.safetensors", config="config.json", torch_dtype=torch.bfloat16)
pipe = FluxPipeline.from_pretrained(
    "black-forest-labs/FLUX.1-dev", 
    torch_dtype=torch.bfloat16,
    transformer=model, 
).to("cuda")
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers

# %%
images = pipe("A group of people racing down a snow-covered slope, their faces obscured by shadows, evoking creepiness and fear. The scene feels empty and lonely, with muted colors and blurred motion amplifying anxiety and frustration, while no single figure stands out prominently.")
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]

# %%
images.images[0]
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>
