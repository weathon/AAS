# %%
import numpy as np
hpsv2 = [np.float16(-0.0818), np.float16(-0.03882), np.float16(0.02808), np.float16(-0.0581), np.float16(0.04626), np.float16(-0.002197), np.float16(-0.02393), np.float16(-0.003418), np.float16(-0.04907), np.float16(0.04016), np.float16(0.05322)]
anti_aesthetics = [np.float16(0.1438), np.float16(0.1823), np.float16(0.549), np.float16(0.3677), np.float16(0.8413), np.float16(0.10004), np.float16(0.5947), np.float16(-0.03644), np.float16(0.3008), np.float16(-0.0935), np.float16(0.2333)]

# %%
import pylab
pylab.scatter(hpsv2, anti_aesthetics)

# %%
import pickle
with open("hpsv3_rewards.pkl", "rb") as f:
    hpsv3_rewards = pickle.load(f)

# %%
delta_hpsv3 = [(i["hpsv3_diop"] - i["hpsv3_oiop"])[0].item() for i in hpsv3_rewards]

# %%
import numpy as np
np.mean(delta_hpsv3)
# Out:
# -4.701567428906759

# %%
hpsv3_after = [i["hpsv3_diop"][0].item() for i in hpsv3_rewards]
np.mean(hpsv3_after)
# Out:
# 6.159045421133439
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
